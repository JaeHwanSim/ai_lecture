# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.1-cp313-cp313-win_amd64.whl (12.7 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.3.1

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\nbl240603\miniconda3\envs\ai_lecture\lib\site-packages (from scipy) (2.3.1)
# Using cached scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.0

# %%
import numpy as np
import scipy.stats as stats

np.random.seed(0)
sample = np.random.normal(loc=100, scale=15, size=30)

sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

z = 1.96  # 95% 신뢰수준
margin_of_error = z * (sample_std / np.sqrt(n))

ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"표본 평균: {sample_mean:.2f}")
print(f"95% 신뢰구간: ({ci_lower:.2f}, {ci_upper:.2f})")

t_stat, p_value = stats.ttest_1samp(sample, popmean=100)

print(f"t통계량: {t_stat:.2f}, p값: {p_value:.4f}")


alpha = 0.05

if p_value < alpha:
    print("귀무가설 기각: 통계적으로 유의미한 차이 존재")
else:
    print("귀무가설 채택: 유의미한 차이 없음")
# Out:
# 표본 평균: 106.64
# 95% 신뢰구간: (100.74, 112.55)
# t통계량: 2.20, p값: 0.0356
# 귀무가설 기각: 통계적으로 유의미한 차이 존재

# %%
import numpy as np
from scipy.stats import pearsonr

x = [10, 20, 30, 40, 50]
y = [15, 25, 35, 45, 55]

r, p = pearsonr(x, y)

print(f"피어슨 상관 계수 r: {r:.2f}, p값: {p:.4f}")
# Out:
# 피어슨 상관 계수 r: 1.00, p값: 0.0000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'Math': [90, 85, 78, 92, 88],
    'Korean': [91, 89, 75, 95, 90],
    'English': [80, 70, 65, 85, 78]
})

corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation between Subjects")
plt.show()
